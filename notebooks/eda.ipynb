# %% [markdown]
# <h3>EDA analysis of datasets</h3>

# %% [markdown]
# <h4>Flight sample dataset</h4>

# %%
import pandas as pd

# %% [markdown]
# <p>Download and save parquet file with flight data</p>

# %%
# !wget -O ./data/flight_sample.parquet https://www.eurocontrol.int/performance/data/download/OPDI/v002/flight_list/flight_list_202501.parquet
# Out:
# --2026-03-21 14:18:18--  https://www.eurocontrol.int/performance/data/download/OPDI/v002/flight_list/flight_list_202501.parquet
# Resolving www.eurocontrol.int (www.eurocontrol.int)... 104.18.10.65, 104.18.11.65, 2606:4700::6812:b41, ...
# Connecting to www.eurocontrol.int (www.eurocontrol.int)|104.18.10.65|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 33922640 (32M)
# Saving to: ‘./data/flight_sample.parquet’
#
# ./data/flight_sampl 100%[===================>]  32.35M  6.14MB/s    in 5.5s
#
# 2026-03-21 14:18:24 (5.87 MB/s) - ‘./data/flight_sample.parquet’ saved [33922640/33922640]

# %% [markdown]
# <p>Observe the dataframe</p>

# %%
data = pd.read_parquet('./data/flight_sample.parquet')

# %%
data.head(20)
# Out:
#                  id  icao24    flt_id        dof  adep  ades adep_p ades_p  \
# 0     3488005984615  4baa93  TKJ1DK   2025-01-01  LTFJ   NaN
# 1     5868520310734  4867b0  TRA6411  2025-01-31  EHAM   NaN
# 2    15826809206891  0a0089       NaN 2025-01-25   NaN   NaN    NaN    NaN
# 3    21477029090992  447c52           2025-01-28   NaN   NaN    NaN    NaN
# 4    29235037659640  4d2502  RYR404A  2025-01-11  LPPR  LEBL
# 5    41158732645012  4856c9  KLM7925  2025-01-29   NaN   NaN    NaN    NaN
# 6    43481741877832  3c56ee  EWG1CR   2025-01-04  EDDH   NaN
# 7    55432238206495  4bcdd5  SXS4F    2025-01-09  LTBJ   NaN
# 8    60656829030530  39260d  FGJQN    2025-01-17  LFRI   NaN
# 9    97375436269383  407dcd  BCI554   2025-01-31  EGJJ  EGNX
# 10  100867123757222  47bf10  DOC88    2025-01-03  EKOD  EKRK
# 11  131421262909327  3c658c           2025-01-11   NaN  ENZV
# 12  132507638280761  395141  METAL85  2025-01-09  LFCY  LFBG
# ...

# %%
data.columns
# Out:
# Index(['id', 'icao24', 'flt_id', 'dof', 'adep', 'ades', 'adep_p', 'ades_p',
#        'registration', 'model', 'typecode', 'icao_aircraft_class',
#        'icao_operator', 'first_seen', 'last_seen', 'version', 'unix_time'],
#       dtype='str')

# %%
data.info
# Out:
# <bound method DataFrame.info of                            id  icao24    flt_id        dof  adep  ades adep_p  \
# 0               3488005984615  4baa93  TKJ1DK   2025-01-01  LTFJ   NaN
# 1               5868520310734  4867b0  TRA6411  2025-01-31  EHAM   NaN
# 2              15826809206891  0a0089       NaN 2025-01-25   NaN   NaN    NaN
# 3              21477029090992  447c52           2025-01-28   NaN   NaN    NaN
# 4              29235037659640  4d2502  RYR404A  2025-01-11  LPPR  LEBL
# ...                       ...     ...       ...        ...   ...   ...    ...
# 1036083  18446645549571433878  503d79  AHY064   2025-01-02  EDDB   NaN
# 1036084  18446688588963210670  4d23f8  RYR9XU   2025-01-25  EDDK   NaN
# 1036085  18446714180884428886  398de4  FHDPE    2025-01-21   NaN   NaN    NaN
# 1036086  18446739526091475838  486802  KLM1322  2025-01-24  EPKK  EHAM
# 1036087  18446740993063977924  407598  BZE03A   2025-01-22   NaN   NaN    NaN
#
# ...

# %%
data.describe(include="all")
# Out:
#                   id   icao24  flt_id                         dof    adep  \
# count   1.036088e+06  1036088  943975                     1036088  509668
# unique           NaN    28314   88556                         NaN     770
# top              NaN   5113e1                                 NaN    EGLL
# freq             NaN      459   19245                         NaN   18302
# mean    9.223361e+18      NaN     NaN  2025-01-15 06:00:03.419015     NaN
# min     3.488006e+12      NaN     NaN         2025-01-01 00:00:00     NaN
# 25%     4.615414e+18      NaN     NaN         2025-01-08 00:00:00     NaN
# 50%     9.226621e+18      NaN     NaN         2025-01-15 00:00:00     NaN
# 75%     1.383464e+19      NaN     NaN         2025-01-22 00:00:00     NaN
# max     1.844674e+19      NaN     NaN         2025-01-31 00:00:00     NaN
# std     5.322051e+18      NaN     NaN                         NaN     NaN
#
#           ades  adep_p  ades_p registration     model typecode  \
# ...

# %%
data.nunique()
# Out:
# id                     1035898
# icao24                   28314
# flt_id                   88556
# dof                         31
# adep                       770
# ades                       877
# adep_p                     473
# ades_p                     802
# registration             24035
# model                     3740
# typecode                   752
# icao_aircraft_class         23
# icao_operator              757
# first_seen              396259
# last_seen               385550
# version                      1
# unix_time               396259
# dtype: int64

# %%
data.shape
# Out:
# (1036088, 17)

# %%
data.duplicated('id')
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1036083    False
# 1036084    False
# 1036085    False
# 1036086    False
# 1036087    False
# Length: 1036088, dtype: bool

# %% [markdown]
# <p>check for possible duplicate id</p>

# %%
data_duplicated = data[data['id'].duplicated(keep=False)]

# %%
data_duplicated.to_csv('./data/duplicated.csv')

# %%
data_duplicated.shape
# Out:
# (380, 17)

# %% [markdown]
# <p>datatypes</p>

# %%
data.dtypes
# Out:
# id                             uint64
# icao24                            str
# flt_id                            str
# dof                    datetime64[us]
# adep                              str
# ades                              str
# adep_p                            str
# ades_p                            str
# registration                      str
# model                             str
# typecode                          str
# icao_aircraft_class               str
# icao_operator                     str
# first_seen             datetime64[us]
# last_seen              datetime64[us]
# version                           str
# unix_time                       int64
# dtype: object

# %% [markdown]
# <p>Persentage of null values</p>

# %%
data.isna().mean()
# Out:
# id                     0.000000
# icao24                 0.000000
# flt_id                 0.088905
# dof                    0.000000
# adep                   0.508084
# ades                   0.466102
# adep_p                 0.297802
# ades_p                 0.297802
# registration           0.111361
# model                  0.357314
# typecode               0.113208
# icao_aircraft_class    0.250014
# icao_operator          0.441079
# first_seen             0.000000
# last_seen              0.000000
# version                0.000000
# unix_time              0.000000
# dtype: float64

# %%
data[data['flt_id'].isna()].head()
# Out:
#                  id  icao24 flt_id        dof adep ades adep_p ades_p  \
# 2    15826809206891  0a0089    NaN 2025-01-25  NaN  NaN    NaN    NaN
# 17  232659967406349  4bcde7    NaN 2025-01-22  NaN  NaN    NaN    NaN
# 25  424562569716327  4ca3e3    NaN 2025-01-02  NaN  NaN    NaN    NaN
# 26  437309451548656  47bf37    NaN 2025-01-10  NaN  NaN    NaN    NaN
# 43  791592936167435  a3ea54    NaN 2025-01-20  NaN  NaN    NaN    NaN
#
#    registration        model typecode icao_aircraft_class icao_operator  \
# 2        7T-VUW   ATR 72 600     AT76                 L2T           DAH
# 17       TC-SOG  737NG 800/W     B738                 L2J           SXS
# 25          NaN          NaN      NaN                 NaN           NaN
# 26       LN-OUJ         H135     EC35                 H2T           DOC
# 43       N351UP     767-34AF     B763                 L2J           UPS
#
#             first_seen           last_seen version   unix_time
# ...

# %% [markdown]
# <h4>Airports dataset</h4>

# %% [markdown]
# <p>Download and save dataset</p>

# %%
# !wget -P ./data/ https://davidmegginson.github.io/ourairports-data/airports.csv
# Out:
# --2026-03-21 15:12:37--  https://davidmegginson.github.io/ourairports-data/airports.csv
# Resolving davidmegginson.github.io (davidmegginson.github.io)... 185.199.109.153, 185.199.110.153, 185.199.108.153, ...
# Connecting to davidmegginson.github.io (davidmegginson.github.io)|185.199.109.153|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12563575 (12M) [text/csv]
# Saving to: ‘./data/airports.csv’
#
# airports.csv        100%[===================>]  11.98M  5.98MB/s    in 2.0s
#
# 2026-03-21 15:12:40 (5.98 MB/s) - ‘./data/airports.csv’ saved [12563575/12563575]

# %% [markdown]
# <p>Observe the dataframe</p>

# %%
airp = pd.read_csv('./data/airports.csv')

# %%
airp.head(20)
# Out:
#         id ident           type                               name  \
# 0     6523   00A       heliport                  Total RF Heliport
# 1   323361  00AA  small_airport               Aero B Ranch Airport
# 2     6524  00AK  small_airport                       Lowell Field
# 3     6525  00AL  small_airport                       Epps Airpark
# 4   506791  00AN  small_airport               Katmai Lodge Airport
# 5   322127  00AS  small_airport                     Fulton Airport
# 6     6527  00AZ  small_airport                     Cordes Airport
# 7     6528  00CA  small_airport            Goldstone (GTS) Airport
# 8   324424  00CL  small_airport                Williams Ag Airport
# 9   322658  00CN       heliport    Kitchen Creek Helibase Heliport
# 10    6531  00FA  small_airport                Grass Patch Airport
# 11    6533  00FL  small_airport                  River Oak Airport
# 12    6534  00GA  small_airport                   Lt World Airport
# ...

# %%
airp.columns
# Out:
# Index(['id', 'ident', 'type', 'name', 'latitude_deg', 'longitude_deg',
#        'elevation_ft', 'continent', 'iso_country', 'iso_region',
#        'municipality', 'scheduled_service', 'icao_code', 'iata_code',
#        'gps_code', 'local_code', 'home_link', 'wikipedia_link', 'keywords'],
#       dtype='str')

# %%
airp.dtypes
# Out:
# id                     int64
# ident                    str
# type                     str
# name                     str
# latitude_deg         float64
# longitude_deg        float64
# elevation_ft         float64
# continent                str
# iso_country              str
# iso_region               str
# municipality             str
# scheduled_service        str
# icao_code                str
# iata_code                str
# gps_code                 str
# local_code               str
# home_link                str
# wikipedia_link           str
# keywords                 str
# dtype: object

# %%
airp.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 84934 entries, 0 to 84933
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 84934 non-null  int64
#  1   ident              84934 non-null  str
#  2   type               84934 non-null  str
#  3   name               84934 non-null  str
#  4   latitude_deg       84934 non-null  float64
#  5   longitude_deg      84934 non-null  float64
#  6   elevation_ft       70230 non-null  float64
#  7   continent          45444 non-null  str
#  8   iso_country        84642 non-null  str
#  9   iso_region         84934 non-null  str
#  10  municipality       80177 non-null  str
#  11  scheduled_service  84934 non-null  str
#  12  icao_code          9816 non-null   str
#  13  iata_code          9063 non-null   str
#  14  gps_code           43996 non-null  str
#  15  local_code         35985 non-null  str
#  16  home_link          4661 non-null   str
# ...

# %% [markdown]
# <p>Airport identifiers (Idents) are unique codes designating airports worldwide,
# primarily IATA (3-letter) and ICAO (4-letter) codes used for identification,
# flight planning, and navigation.</p>

# %% [markdown]
# <p>Check for possible duplicates for the key column</p>

# %%
airp_duplicated = airp[airp['ident'].duplicated(keep=False)]

# %%
airp_duplicated
# Out:
# Empty DataFrame
# Columns: [id, ident, type, name, latitude_deg, longitude_deg, elevation_ft, continent, iso_country, iso_region, municipality, scheduled_service, icao_code, iata_code, gps_code, local_code, home_link, wikipedia_link, keywords]
# Index: []
